# %%
body = client_ebd2864b8f7f4aac816a7f5baf5030b5.get_object(Bucket='wewer-donotdelete-pr-dtsvsarrhg5bfv',Key='GoSales.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_5 = pd.read_csv(body)
df_data_5.head()
# Out:
#   GENDER  AGE MARITAL_STATUS    PROFESSION  IS_TENT          PRODUCT_LINE  \
# 0      M   27         Single  Professional     True     Camping Equipment
# 1      F   39        Married         Other    False    Outdoor Protection
# 2      F   39        Married         Other    False    Outdoor Protection
# 3      F   56    Unspecified   Hospitality    False  Personal Accessories
# 4      M   45        Married       Retired    False        Golf Equipment
#
#    PURCHASE_AMOUNT
# 0           144.78
# 1           144.83
# 2           137.37
# 3            92.61
# 4           119.04

# %%
import numpy as np
from sklearn import datasets, linear_model
import matplotlib.pyplot as plt

# %%
x = df_data_5.AGE

y = df_data_5.PURCHASE_AMOUNT

# %%
##GRAFICO
plt.scatter(x,y)
plt.xlabel("Edad")
plt.ylabel("Y")
plt.show()

# %%
# Edad
df_data_5["AGE"].value_counts(bins = 5 , normalize = True)

# %%
#######graff


plt.scatter(x_test,y_test)
plt.plot(x_test, y_pred,color='red',linewidth=3)
plt.xlabel("habit")
plt.ylabel("valor medio")
plt.show()

print()
lr.coef_
print(lr.score(x_train,y_train))

# %%
list(df_data_5.columns)
# Out:
# ['GENDER',
#  'AGE',
#  'MARITAL_STATUS',
#  'PROFESSION',
#  'IS_TENT',
#  'PRODUCT_LINE',
#  'PURCHASE_AMOUNT']

# %%
# %matplotlib inline

# %%
n, bins, patches = plt.hist(x=df_data_5['AGE'].dropna(), bins=12, density=False, color='green', alpha=0.75)
plt.xlabel('Antiguedad')
plt.ylabel('Densidad')
plt.title('Histograma de Antiguedad')

plt.grid(True)

# %%
x = plt.boxplot(x=df_data_5['AGE'].dropna())

# %%
x = plt.boxplot(x=df_data_5['PURCHASE_AMOUNT'].dropna())

# %%
N = len(df_data_5['PURCHASE_AMOUNT'])
colors = np.random.rand(N)
area = (4 * np.random.rand(N))**2
plt.scatter(df_data_5['PURCHASE_AMOUNT'], df_data_5['AGE'], s=area, c=colors, alpha=0.5)
plt.xlabel('Antiguedad')
plt.ylabel('Edad')
plt.title('Relación Antiguedad - Edad')

#plt.grid(True)
# Out:
# Text(0.5, 1.0, 'Relación Antiguedad - Edad')
